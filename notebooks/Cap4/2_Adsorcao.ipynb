# %% [markdown]
# # Adsorção usando VASP e ASE
#
# Autor: [Prof. Elvis do A. Soares](https://github.com/elvissoares)
#
# Contato: [elvis@peq.coppe.ufrj.br](mailto:elvis@peq.coppe.ufrj.br) - [Programa de Engenharia Química, PEQ/COPPE, UFRJ, Brasil](https://www.peq.coppe.ufrj.br/)
#
# ---

# %% [markdown]
# Importando variáveis do VASP

# %%
import os
# Definindo o path para os arquivos de potencial de pseudopotenciais do VASP
# Certifique-se de que o caminho esteja correto para o seu sistema
os.environ['VASP_PP_PATH'] = '/home/elvis/Programs/vasp-6.5.1/pp'
os.environ['ASE_VASP_COMMAND'] = 'mpirun -np 1 vasp_std_gpu'
os.environ['NO_STOP_MESSAGE'] = '1' # to avoid warning from mpirun

# Importando o VASP calculator do ASE
from ase.calculators.vasp import Vasp

# %%
import numpy as np
import matplotlib.pyplot as plt

from ase import Atoms, Atom
from ase.build import molecule

from ase.io import read, write
from ase.visualize import view

# %% [markdown]
# # Adsorção de O2 em Ag(111)
#
# Ref: https://journals.aps.org/prb/pdf/10.1103/PhysRevB.65.075407

# %% [markdown]
# ## Átomo de O

# %%
atom = Atoms([Atom('O', [0,0,0])])
atom.center(vacuum=4.0)       # ~8 Å box; 4 Å para cada lado, bom para isolar molécula
atom.pbc = True               # aplica condição de contorno periódica

# %%
view(atom, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 16.0">
#     <group/>
#   </viewpoint>
#   <transform translation="-4.0 -4.0 -4.0">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.0 0.0 0.0 8.0 8.0 0.0 0.0 8.0 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 8.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.0 0.0 0.0 8.0 8.0 0.0 0.0 8.0 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.0 0.0 0.0 8.0 0.0 8.0 0.0 0.0 8.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 8.0 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.0 0.0 0.0 8.0 0.0 8.0 0.0 0.0 8.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="4.0 4.0 4.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#       </group>
#     </group>
#   </transform>
# </scene>
# <!--End of Inserted Scene-->
#
#         </X3D>
#     </body>
# </html>

# %%
calc = Vasp(directory='adsorcao/O',
            xc='PBE',                                   # funcional
            encut=450,                                  # safe default for PAW-PBE sets
            kpts=[1, 1, 1],gamma=True,                  # k-points
            ismear=0, sigma=0.05,                       # Gaussian smearing for molecules
            ediff=1e-6, ediffg=-0.02,                   # SCF and force criteria (~0.02 eV/Å)
            ibrion=2, isif=0, nsw=150,                  # CG ionic relax; fixed cell
            lreal='Auto',
            lwave=True, lcharg=True,lvtot=True,  # keep WAVECAR/CHGCAR/LOCPOT for post-processing
            atoms=atom)

# %%
E_O = atom.get_potential_energy()       

print('Energia do átomo de O = {:.3f} eV'.format(E_O))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 E_O = atom.get_potential_energy()
#       3 print('Energia do átomo de O = {:.3f} eV'.format(E_O))
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/site-packages/ase/atoms.py:835, in Atoms.get_potential_energy(self, force_consistent, apply_constraint)
#     832     energy = self._calc.get_potential_energy(
#     833         self, force_consistent=force_consistent)
#     834 else:
# --> 835     energy = self._calc.get_potential_energy(self)
#     836 if apply_constraint:
#     837     for constraint in self.constraints:
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/site-packages/ase/calculators/abc.py:26, in GetPropertiesMixin.get_potential_energy(self, atoms, force_consistent)
#      24 else:
#      25     name = 'energy'
# ---> 26 return self.get_property(name, atoms)
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/site-packages/ase/calculators/calculator.py:519, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     516     if self.use_cache:
#     517         self.atoms = atoms.copy()
# --> 519     self.calculate(atoms, [name], system_changes)
#     521 if name not in self.results:
#     522     # For some reason the calculator was not able to do what we want,
#     523     # and that is OK.
#     524     raise PropertyNotImplementedError(
#     525         '{} not present in this ' 'calculation'.format(name)
#     526     )
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/site-packages/ase/calculators/vasp/vasp.py:337, in Vasp.calculate(self, atoms, properties, system_changes)
#     334 self.write_input(self.atoms, properties, system_changes)
#     336 with self._txt_outstream() as out:
# --> 337     errorcode, stderr = self._run(command=command,
#     338                                   out=out,
#     339                                   directory=self.directory)
#     341 if errorcode:
#     342     raise calculator.CalculationFailed(
#     343         '{} in {} returned an error: {:d} stderr {}'.format(
#     344             self.name, Path(self.directory).resolve(), errorcode,
#     345             stderr))
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/site-packages/ase/calculators/vasp/vasp.py:357, in Vasp._run(self, command, out, directory)
#     355 if directory is None:
#     356     directory = self.directory
# --> 357 result = subprocess.run(command,
#     358                         shell=True,
#     359                         cwd=directory,
#     360                         capture_output=True,
#     361                         text=True)
#     362 if out is not None:
#     363     out.write(result.stdout)
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/subprocess.py:556, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
# --> 556         stdout, stderr = process.communicate(input, timeout=timeout)
#     557     except TimeoutExpired as exc:
#     558         process.kill()
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/subprocess.py:1222, in Popen.communicate(self, input, timeout)
#    1219     endtime = None
#    1221 try:
# -> 1222     stdout, stderr = self._communicate(input, endtime, timeout)
#    1223 except KeyboardInterrupt:
#    1224     # https://bugs.python.org/issue25942
#    1225     # See the detailed comment in .wait().
#    1226     if timeout is not None:
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/subprocess.py:2128, in Popen._communicate(self, input, endtime, orig_timeout)
#    2121     self._check_timeout(endtime, orig_timeout,
#    2122                         stdout, stderr,
#    2123                         skip_check_and_raise=True)
#    2124     raise RuntimeError(  # Impossible :)
#    2125         '_check_timeout(..., skip_check_and_raise=True) '
#    2126         'failed to raise TimeoutExpired.')
# -> 2128 ready = selector.select(timeout)
#    2129 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2131 # XXX Rewrite these to use non-blocking I/O on the file
#    2132 # objects; they are no longer using C stdio!
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/selectors.py:398, in _PollLikeSelector.select(self, timeout)
#     396 ready = []
#     397 try:
# --> 398     fd_event_list = self._selector.poll(timeout)
#     399 except InterruptedError:
#     400     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# ## Molécula de O2

# %% [markdown]
# Otimização da geometria da molécula de O2

# %%
molecule = Atoms([Atom('O', [0, 0, -0.66]),
                  Atom('O', [0, 0, 0.66])])
molecule.center(vacuum=4.0)       # ~8 Å box; 4 Å para cada lado, bom para isolar molécula
molecule.pbc = True               # aplica condição de contorno periódica

# %%
calc = Vasp(directory='adsorcao/O2',
            xc='PBE',                                   # funcional
            encut=450,                                  # safe default for PAW-PBE sets
            kpts=[1, 1, 1],gamma=True,                  # k-points
            ismear=0, sigma=0.05,                       # Gaussian smearing for molecules
            ediff=1e-6, ediffg=-0.02,                   # SCF and force criteria (~0.02 eV/Å)
            ibrion=2, isif=0, nsw=150,                  # CG ionic relax; fixed cell
            lreal='Auto',
            lwave=True, lcharg=True,lvtot=True,  # keep WAVECAR/CHGCAR/LOCPOT for post-processing
            atoms=molecule)

# %%
E_O2 = molecule.get_potential_energy()       

print('Energia da molécula de O2 {:.3f} eV'.format(E_O2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 E_O2 = molecule.get_potential_energy()
#       3 print('Energia da molécula de O2 {:.3f} eV'.format(E_O2))
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/site-packages/ase/atoms.py:835, in Atoms.get_potential_energy(self, force_consistent, apply_constraint)
#     832     energy = self._calc.get_potential_energy(
#     833         self, force_consistent=force_consistent)
#     834 else:
# --> 835     energy = self._calc.get_potential_energy(self)
#     836 if apply_constraint:
#     837     for constraint in self.constraints:
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/site-packages/ase/calculators/abc.py:26, in GetPropertiesMixin.get_potential_energy(self, atoms, force_consistent)
#      24 else:
#      25     name = 'energy'
# ---> 26 return self.get_property(name, atoms)
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/site-packages/ase/calculators/calculator.py:519, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     516     if self.use_cache:
#     517         self.atoms = atoms.copy()
# --> 519     self.calculate(atoms, [name], system_changes)
#     521 if name not in self.results:
#     522     # For some reason the calculator was not able to do what we want,
#     523     # and that is OK.
#     524     raise PropertyNotImplementedError(
#     525         '{} not present in this ' 'calculation'.format(name)
#     526     )
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/site-packages/ase/calculators/vasp/vasp.py:337, in Vasp.calculate(self, atoms, properties, system_changes)
#     334 self.write_input(self.atoms, properties, system_changes)
#     336 with self._txt_outstream() as out:
# --> 337     errorcode, stderr = self._run(command=command,
#     338                                   out=out,
#     339                                   directory=self.directory)
#     341 if errorcode:
#     342     raise calculator.CalculationFailed(
#     343         '{} in {} returned an error: {:d} stderr {}'.format(
#     344             self.name, Path(self.directory).resolve(), errorcode,
#     345             stderr))
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/site-packages/ase/calculators/vasp/vasp.py:357, in Vasp._run(self, command, out, directory)
#     355 if directory is None:
#     356     directory = self.directory
# --> 357 result = subprocess.run(command,
#     358                         shell=True,
#     359                         cwd=directory,
#     360                         capture_output=True,
#     361                         text=True)
#     362 if out is not None:
#     363     out.write(result.stdout)
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/subprocess.py:556, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
# --> 556         stdout, stderr = process.communicate(input, timeout=timeout)
#     557     except TimeoutExpired as exc:
#     558         process.kill()
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/subprocess.py:1222, in Popen.communicate(self, input, timeout)
#    1219     endtime = None
#    1221 try:
# -> 1222     stdout, stderr = self._communicate(input, endtime, timeout)
#    1223 except KeyboardInterrupt:
#    1224     # https://bugs.python.org/issue25942
#    1225     # See the detailed comment in .wait().
#    1226     if timeout is not None:
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/subprocess.py:2128, in Popen._communicate(self, input, endtime, orig_timeout)
#    2121     self._check_timeout(endtime, orig_timeout,
#    2122                         stdout, stderr,
#    2123                         skip_check_and_raise=True)
#    2124     raise RuntimeError(  # Impossible :)
#    2125         '_check_timeout(..., skip_check_and_raise=True) '
#    2126         'failed to raise TimeoutExpired.')
# -> 2128 ready = selector.select(timeout)
#    2129 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2131 # XXX Rewrite these to use non-blocking I/O on the file
#    2132 # objects; they are no longer using C stdio!
#
# File ~/Programs/miniforge3/envs/quantum/lib/python3.13/selectors.py:398, in _PollLikeSelector.select(self, timeout)
#     396 ready = []
#     397 try:
# --> 398     fd_event_list = self._selector.poll(timeout)
#     399 except InterruptedError:
#     400     return ready
#
# KeyboardInterrupt:

# %%
molecule.get_distance(0, 1)  # distância entre os átomos 0 e 1
# Out:
# np.float64(1.2352362189856132)

# %% [markdown]
# $O_2 \to 2 O$

# %%
E_bind = 2 * E_O - E_O2

print("O2 -> 2 O --- E_bind = {0:1.3f} eV".format(E_bind))
print("(1/2)E_bind = {0:1.3f} eV".format(0.5*E_bind))
# Out:
# O2 -> 2 O --- E_bind = 8.652 eV
# (1/2)E_bind = 4.326 eV

# %% [markdown]
# The experimental values are $1/2 E_b^{O_2}= 2.56$ eV, $d_0 = 2.28$ bohrs, and $\omega = 196$ meV (1580 $\text{cm}^{-1}$).
#
# Ref: K. P. Huber and G. Herzberg, *Molecular Spectra and Molecular Structure IV: Constants of Diatomic Molecules* (Van Nostrand Reinhold, New York, 1979).

# %%
molecule.get_all_distances()
# Out:
# array([[0.        , 1.23523622],
#        [1.23523622, 0.        ]])

# %%
view(molecule, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 18.64">
#     <group/>
#   </viewpoint>
#   <transform translation="-4.0 -4.0 -4.66">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.0 0.0 0.0 8.0 8.0 0.0 0.0 8.0 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 9.32">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.0 0.0 0.0 8.0 8.0 0.0 0.0 8.0 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.0 0.0 0.0 8.0 0.0 9.32 0.0 0.0 9.32 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 8.0 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.0 0.0 0.0 8.0 0.0 9.32 0.0 0.0 9.32 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="4.0 4.0 4.042381890507193">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#         <transform translation="4.0 4.0 5.277618109492806">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#       </group>
#     </group>
#   </transform>
# </scene>
# <!--End of Inserted Scene-->
#
#         </X3D>
#     </body>
# </html>

# %% [markdown]
# ## Estado fundamental da molécula de O2
#
# A molécula de O2 tem como estado fundamental um tripleto de spin. Assim, a molécula de O2 no estado fundamental possui dois elétrons desemparelhados.

# %% [markdown]
# Correção de polarização de spin: `ISPIN` = 2

# %%
atom = Atoms([Atom('O', [0,0,0], magmom=2)])    # com momento magnético inicial
atom.center(vacuum=4.0)                        # ~8 Å box; 4 Å para cada lado, bom para isolar molécula
atom.pbc = True                                  # aplica condição de contorno periódica

calc = Vasp(directory='adsorcao/O-sp-triplet',
            xc='PBE',                                   # funcional
            encut=450,                                  # safe default for PAW-PBE sets
            kpts=[1, 1, 1],gamma=True,                  # k-points
            ismear=0, sigma=0.05,                       # Gaussian smearing for molecules
            ediff=1e-6, ediffg=-0.02,                   # SCF and force criteria (~0.02 eV/Å)
            ibrion=2, isif=0, nsw=150,                  # CG ionic relax; fixed cell
            ispin=2,                                    # turn spin-polarization on
            lreal='Auto',
            lwave=True, lcharg=True,lvtot=True,  # keep WAVECAR/CHGCAR/LOCPOT for post-processing
            atoms=atom)

E_O = atom.get_potential_energy()       

print('Energia do átomo de O = {:.3f} eV'.format(E_O))

print("Momento magnético do átomo de O = {0} Bohr magnetons".format(atom.get_magnetic_moment()))
# Out:
# Energia do átomo de O = -1.544 eV
# Momento magnético do átomo de O = 1.9999968 Bohr magnetons
# /home/elvis/Programs/miniforge3/envs/quantum/lib/python3.13/site-packages/ase/calculators/vasp/vasp.py:1004: UserWarning: Magnetic moment data not written in OUTCAR (LORBIT<10), setting magnetic_moments to zero.
# Set LORBIT>=10 to get information on magnetic moments
#   warn('Magnetic moment data not written in OUTCAR (LORBIT<10),'

# %%
molecule = Atoms([Atom('O', [0, 0, -0.66], magmom=1),
                  Atom('O', [0, 0, 0.66], magmom=1)]) # com momento magnético inicial
molecule.center(vacuum=4.0)                           # ~8 Å box; 4 Å para cada lado, bom para isolar molécula
molecule.pbc = True                                   # aplica condição de contorno periódica

calc = Vasp(directory='adsorcao/O2-sp-triplet',
            xc='PBE',                                   # funcional
            encut=450,                                  # safe default for PAW-PBE sets
            kpts=[1, 1, 1],gamma=True,                  # k-points
            ismear=0, sigma=0.05,                       # Gaussian smearing for molecules
            ediff=1e-6, ediffg=-0.02,                   # SCF and force criteria (~0.02 eV/Å)
            ibrion=2, isif=0, nsw=150,                  # CG ionic relax; fixed cell
            ispin=2,                                    # turn spin-polarization on
            lreal='Auto',
            lwave=True, lcharg=True,lvtot=True,  # keep WAVECAR/CHGCAR/LOCPOT for post-processing
            atoms=molecule)

E_O2 = molecule.get_potential_energy()       

print('Energia da molécula de O2 = {:.3f} eV'.format(E_O2))

print("Momento magnético da molécula de O2 = {0} Bohr magnetons".format(molecule.get_magnetic_moment()))
# Out:
# Energia da molécula de O2 = -9.856 eV
# Momento magnético da molécula de O2 = 1.9999968 Bohr magnetons

# %% [markdown]
# Energia de ligação da molécula

# %%
E_bind = 2 * E_O - E_O2

print("O2 -> 2 O --- E_bind = {0:1.3f} eV".format(E_bind))

print("(1/2)E_bind = {0:1.3f} eV".format(0.5*E_bind))
# Out:
# O2 -> 2 O --- E_bind = 6.768 eV
# (1/2)E_bind = 3.384 eV

# %%
molecule.get_all_distances()
# Out:
# array([[0.        , 1.23368752],
#        [1.23368752, 0.        ]])

# %% [markdown]
# ## Vibração da molécula de O2 e energia de ponto zero (ZPE)
#
# Vimos que para uma molécula diatômica, podemos aproximar o movimento nuclear próximo do equilíbrio como um oscilador harmônico. A quantização dos estados de energia desse oscilador harmônico leva a um espectro de energia do tipo
#
# $$E_n = \hbar \omega\left( n + \frac{1}{2}\right)$$
#
# sendo $n$ um número quântico positivo e $\omega = \sqrt{k/m}$ a frequência angular de vibração da molécula.

# %% [markdown]
# Usando o VASP, podemos calcular as frequências de vibração da molécula de O2.
#
#
# Para isso, vamos abrir um cálculo que já foi executado

# %%
calc = Vasp(restart=True, directory='adsorcao/O2-sp-triplet')

molecule = calc.get_atoms()

# %%
# now do the vibrations
calc.set(directory='adsorcao/O2-sp-triplet-vib',
        ibrion=6,       # diferenças finitas para cálculo de vibração (with symmetry)
        nfree=2,        # usa diferenças centradas
        potim=0.02,     # tamanho do passo (em Å)
        nsw=1,
        atoms=molecule)

# %%
molecule.get_potential_energy()
# Out:
# -9.84213325

# %%
vib_freq = calc.read_vib_freq()

for i, f in enumerate(vib_freq[0]):
    print("{0:02d}: {1} meV".format(i, f))
# Out:
# 00: 194.114377 meV
# 01: 1e-06 meV
# 02: 0.0 meV
# 03: 0.0 meV

# %% [markdown]
# Os valores experimentais são $1/2 E_b^{O_2}= 2.56$ eV, $d_0 = 2.28$ bohrs, and $\omega = 196$ meV (1580 $\text{cm}^{-1}$).
#
# Ref: K. P. Huber and G. Herzberg, *Molecular Spectra and Molecular Structure IV: Constants of Diatomic Molecules* (Van Nostrand Reinhold, New York, 1979).

# %% [markdown]
# ## Superfície Cristalina Ag(111)

# %%
from ase.build import (
    fcc100, fcc110, fcc111, fcc211, fcc111_root,
    bcc100, bcc110, bcc111, bcc111_root,
    hcp0001, hcp10m10, hcp0001_root,
    diamond100, diamond111
)

slab = fcc111("Ag", size=(2,2,3), vacuum=10.0,periodic=True)

print(slab)
print("Cell:", slab.get_cell())
# Out:
# Atoms(symbols='Ag12', pbc=True, cell=[[5.784133470105959, 0.0, 0.0], [2.8920667350529796, 5.009206523991598, 0.0], [0.0, 0.0, 24.722725201971137]], tags=...)
# Cell: Cell([[5.784133470105959, 0.0, 0.0], [2.8920667350529796, 5.009206523991598, 0.0], [0.0, 0.0, 24.722725201971137]])

# %%
view(slab, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 49.445450403942274">
#     <group/>
#   </viewpoint>
#   <transform translation="-2.8920667350529796 -2.504603261995799 -12.361362600985569">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 8.676200205158938 5.009206523991598 0.0 2.8920667350529796 5.009206523991598 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 24.722725201971137">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 8.676200205158938 5.009206523991598 0.0 2.8920667350529796 5.009206523991598 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 5.784133470105959 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 5.009206523991598 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 5.784133470105959 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="1.4460333675264898 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105959 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="-5.3513984633472004e-17 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264896 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264898 2.504603261995799 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 2.504603261995799 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#       </group>
#     </group>
#   </transform>
# </scene>
# <!--End of Inserted Scene-->
#
#         </X3D>
#     </body>
# </html>

# %% [markdown]
# Para aumentar a velocidade do cálculo, nós congelaremos a superfície e permitiremos o adsorvato de relaxar.

# %%
from ase.constraints import FixAtoms

# now we constrain the slab
constraint = FixAtoms(mask=[atom.symbol=='Ag' for atom in slab])
slab.set_constraint(constraint)

# %%
calc = Vasp(directory='adsorcao/Ag-fcc111-slab',
            xc='PBE',
            kpts=[4,4,1],  # specifies k-points
            encut=450,
            lvtot=True,  # keep LOCPOT for post-processing
            atoms=slab)

# %%
E_slab = slab.get_potential_energy()

print("Energia do slab Ag(111) = {:.3f} eV".format(E_slab))
# Out:
# Energia do slab Ag(111) = -29.801 eV

# %%
view(slab, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 49.445450403942274">
#     <group/>
#   </viewpoint>
#   <transform translation="-2.8920667350529796 -2.504603261995799 -12.361362600985569">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 8.676200205158938 5.009206523991598 0.0 2.8920667350529796 5.009206523991598 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 24.722725201971137">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 8.676200205158938 5.009206523991598 0.0 2.8920667350529796 5.009206523991598 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 5.784133470105959 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 5.009206523991598 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 5.784133470105959 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="1.4460333675264898 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105959 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="-5.3513984633472004e-17 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264896 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264898 2.504603261995799 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 2.504603261995799 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#       </group>
#     </group>
#   </transform>
# </scene>
# <!--End of Inserted Scene-->
#
#         </X3D>
#     </body>
# </html>

# %% [markdown]
# # Adsorção

# %% [markdown]
# ## 1. Átomo de O na posição FCC

# %% [markdown]
# Carregando a geometria do slab relaxada

# %%
calc = Vasp(restart=True, directory='adsorcao/Ag-fcc111-slab')

ads_system = fcc111("Ag", size=(2,2,3), vacuum=10.0,periodic=True)
ads_system.calc = calc

# %%
from ase.build import add_adsorbate

add_adsorbate(ads_system, "O", height=1.2, position="fcc")

# %% [markdown]
# Para aumentar a velocidade do cálculo, nós congelaremos a superfície e permitiremos o adsorvato de relaxar.

# %%
constraint = FixAtoms(mask=[atom.symbol=='Ag' for atom in ads_system])
ads_system.set_constraint(constraint)

# %%
view(ads_system, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 49.445450403942274">
#     <group/>
#   </viewpoint>
#   <transform translation="-2.8920667350529796 -2.504603261995799 -12.361362600985569">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 8.676200205158938 5.009206523991598 0.0 2.8920667350529796 5.009206523991598 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 24.722725201971137">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 8.676200205158938 5.009206523991598 0.0 2.8920667350529796 5.009206523991598 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 5.784133470105959 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 5.009206523991598 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 5.784133470105959 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="1.4460333675264898 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105959 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="-5.3513984633472004e-17 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264896 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264898 2.504603261995799 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 2.504603261995799 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264898 0.8348677539985997 15.922725201971138">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#       </group>
#     </group>
#   </transform>
# </scene>
# <!--End of Inserted Scene-->
#
#         </X3D>
#     </body>
# </html>

# %%
# now we set calculation for the adsorbed system
calc.set(directory='adsorcao/Ag-slab-O-fcc',
        xc='PBE',
        kpts=[4, 4, 1],
        encut=450,
        ibrion=2,
        atoms=ads_system)

# %%
E_fcc = ads_system.get_potential_energy()

print("Energia do sistema Ag(111) + O (fcc) = {:.3f} eV".format(E_fcc))
# Out:
# Energia do sistema Ag(111) + O (fcc) = -35.108 eV

# %% [markdown]
# Calculando energia de adsorção
#
# $(1/2) O_2 + Ads \to O-Ads$

# %%
Hads_fcc = E_fcc - E_slab - 0.5 * E_O2

print("Energia de adsorção do O na posição fcc do slab Ag(111) = {:.3f} eV".format(Hads_fcc))
# Out:
# Energia de adsorção do O na posição fcc do slab Ag(111) = -0.380 eV

# %% [markdown]
# ## 2. Átomo de O na posição Bridge

# %%
calc = Vasp(restart=True, directory='adsorcao/Ag-fcc111-slab')

ads_system = fcc111("Ag", size=(2,2,3), vacuum=10.0,periodic=True)
ads_system.calc = calc

# adding O in bridge site
add_adsorbate(ads_system, "O", height=1.2, position="bridge")

# now we constrain the slab
constraint = FixAtoms(mask=[atom.symbol=='Ag' for atom in ads_system])
ads_system.set_constraint(constraint)

# now we set calculation for the adsorbed system
calc.set(directory='adsorcao/Ag-slab-O-bridge',
        xc='PBE',
        kpts=[4, 4, 1],
        encut=450,
        ibrion=2,
        atoms=ads_system)

# %%
view(ads_system, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 49.445450403942274">
#     <group/>
#   </viewpoint>
#   <transform translation="-2.8920667350529796 -2.504603261995799 -12.361362600985569">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 8.676200205158938 5.009206523991598 0.0 2.8920667350529796 5.009206523991598 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 24.722725201971137">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 8.676200205158938 5.009206523991598 0.0 2.8920667350529796 5.009206523991598 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 5.784133470105959 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 5.009206523991598 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 5.784133470105959 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="1.4460333675264898 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105959 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="-5.3513984633472004e-17 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264896 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264898 2.504603261995799 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 2.504603261995799 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264898 0.0 15.922725201971138">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#       </group>
#     </group>
#   </transform>
# </scene>
# <!--End of Inserted Scene-->
#
#         </X3D>
#     </body>
# </html>

# %%
E_bridge = ads_system.get_potential_energy()

print("Energia do sistema Ag(111) + O (bridge) = {:.3f} eV".format(E_bridge))
# Out:
# Energia do sistema Ag(111) + O (bridge) = -34.298 eV

# %% [markdown]
# Demorou 2m 26s

# %%
Hads_bridge = E_bridge - E_slab - 0.5 * E_O2

print("Energia de adsorção do O na posição bridge do slab Ag(111) = {:.3f} eV".format(Hads_bridge))
# Out:
# Energia de adsorção do O na posição bridge do slab Ag(111) = 0.430 eV

# %% [markdown]
# ## 3. Átomo de O na posição HCP

# %%
calc = Vasp(restart=True, directory='adsorcao/Ag-fcc111-slab')

ads_system = fcc111("Ag", size=(2,2,3), vacuum=10.0,periodic=True)
ads_system.calc = calc

# adding O in bridge site
add_adsorbate(ads_system, "O", height=1.2, position="hcp")

# now we constrain the slab
constraint = FixAtoms(mask=[atom.symbol=='Ag' for atom in ads_system])
ads_system.set_constraint(constraint)

# now we set calculation for the adsorbed system
calc.set(directory='adsorcao/Ag-slab-O-hcp',
        xc='PBE',
        kpts=[4, 4, 1],
        encut=450,
        ibrion=2,
        atoms=ads_system)

# %%
view(ads_system, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 49.445450403942274">
#     <group/>
#   </viewpoint>
#   <transform translation="-2.8920667350529796 -2.504603261995799 -12.361362600985569">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 8.676200205158938 5.009206523991598 0.0 2.8920667350529796 5.009206523991598 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 24.722725201971137">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 8.676200205158938 5.009206523991598 0.0 2.8920667350529796 5.009206523991598 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 5.784133470105959 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 5.009206523991598 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 5.784133470105959 0.0 0.0 5.784133470105959 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="1.4460333675264898 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105959 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="-5.3513984633472004e-17 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264896 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264898 2.504603261995799 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 2.504603261995799 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 1.6697355079971994 15.922725201971138">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#       </group>
#     </group>
#   </transform>
# </scene>
# <!--End of Inserted Scene-->
#
#         </X3D>
#     </body>
# </html>

# %%
E_hcp = ads_system.get_potential_energy()

print("Energia do sistema Ag(111) + O (hcp) = {:.3f} eV".format(E_hcp))
# Out:
# Energia do sistema Ag(111) + O (hcp) = -35.010 eV

# %% [markdown]
# Demorou 1m 76s

# %%
Hads_hcp = E_hcp - E_slab - 0.5 * E_O2

print("Energia de adsorção do O na posição hcp do slab Ag(111) = {:.3f} eV".format(Hads_hcp))
# Out:
# Energia de adsorção do O na posição hcp do slab Ag(111) = -0.282 eV

# %% [markdown]
# Comparando as energias de adsorção

# %%
print("Comparando as energias de adsorção")
print("Posição fcc:  {:.3f} eV".format(Hads_fcc))
print("Posição bridge: {:.3f} eV".format(Hads_bridge))
print("Posição hcp:  {:.3f} eV".format(Hads_hcp))
# Out:
# Comparando as energias de adsorção
# Posição fcc:  -0.380 eV
# Posição bridge: 0.430 eV
# Posição hcp:  -0.282 eV

# %% [markdown]
# # Adsorção de moléculas mais complicadas

# %% [markdown]
# Criando a molécula de benzeno

# %%
from ase.build import molecule

# criando a molécula de benzeno
benzene = molecule("C6H6")
benzene.center(vacuum=5)
benzene.pbc = True

calc = Vasp(directory='adsorcao/benzeno',
            xc="PBE",
            encut=450,
            kpts=[1, 1, 1],
            ibrion=2,
            nsw=100,
            ivdw=12,                  # Adicionando correção de van der Waals D3(BJ) (molécula grande)
            atoms=benzene)

E_bezeno = benzene.get_potential_energy()

# %% [markdown]
# Demorou 25.3 s

# %%
print("Energia do benzeno = {:.3f} eV".format(E_bezeno))
# Out:
# Energia do benzeno = -76.290 eV

# %% [markdown]
# Criando o slab de Ag(111)

# %%
# criando um slab Ag(111)
slab = fcc111("Ag", size=(3,3,3), vacuum=10.0,periodic=True)

# now we constrain the slab
constraint = FixAtoms(mask=[atom.symbol=='Ag' for atom in ads_system])
ads_system.set_constraint(constraint)

calc = Vasp(directory='adsorcao/Ag111-slab-vdw',
            xc='PBE',
            kpts=[4,4,1],  
            encut=450,
            ivdw=12,                  # Adicionando correção de van der Waals D3(BJ) (molécula grande)
            atoms=slab)

E_slab_vdw = slab.get_potential_energy()

# %%
view(slab, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 49.445450403942274">
#     <group/>
#   </viewpoint>
#   <transform translation="-4.338100102579469 -3.756904892993699 -12.361362600985569">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.676200205158938 0.0 0.0 13.014300307738408 7.513809785987398 0.0 4.338100102579469 7.513809785987398 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 24.722725201971137">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.676200205158938 0.0 0.0 13.014300307738408 7.513809785987398 0.0 4.338100102579469 7.513809785987398 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.676200205158938 0.0 0.0 8.676200205158938 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 7.513809785987398 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.676200205158938 0.0 0.0 8.676200205158938 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="1.4460333675264896 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579468 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="7.230166837632448 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.892066735052979 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105958 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="8.676200205158938 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 5.844074277990199 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="7.2301668376324475 5.844074277990199 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="10.122233572685428 5.844074277990199 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.0500883674871773e-17 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105958 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264894 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="7.230166837632448 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.892066735052979 6.6789420319887975 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105958 6.6789420319887975 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="8.676200205158938 6.6789420319887975 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.892066735052979 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </tra

# %% [markdown]
# Demorou 3m 53s

# %%
print("Energia do slab Ag(111) = {:.3f} eV".format(E_slab_vdw))
# Out:
# Energia do slab Ag(111) = -78.278 eV

# %% [markdown]
# Criando o sistema de adsorção

# %%
# criando o sistema de adsorção
ads_system = fcc111("Ag", size=(3,3,3), vacuum=10.0,periodic=True)

benz = molecule("C6H6")
benz.center(about=ads_system.get_positions()[-9:].mean(axis=0)) # centraliza o benzeno na superfície do slab
benz.translate([0.0,0.0,2.5])  # altura de 2.5 Å do slab
ads_system += benz

# now we constrain the slab
constraint = FixAtoms(mask=[atom.symbol=='Ag' for atom in ads_system])
ads_system.set_constraint(constraint)

# %%
view(ads_system, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 49.445450403942274">
#     <group/>
#   </viewpoint>
#   <transform translation="-4.338100102579469 -3.756904892993699 -12.361362600985569">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.676200205158938 0.0 0.0 13.014300307738408 7.513809785987398 0.0 4.338100102579469 7.513809785987398 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 24.722725201971137">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.676200205158938 0.0 0.0 13.014300307738408 7.513809785987398 0.0 4.338100102579469 7.513809785987398 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.676200205158938 0.0 0.0 8.676200205158938 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 7.513809785987398 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.676200205158938 0.0 0.0 8.676200205158938 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="1.4460333675264896 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579468 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="7.230166837632448 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.892066735052979 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105958 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="8.676200205158938 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 5.844074277990199 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="7.2301668376324475 5.844074277990199 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="10.122233572685428 5.844074277990199 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.0500883674871773e-17 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105958 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264894 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="7.230166837632448 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.892066735052979 6.6789420319887975 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105958 6.6789420319887975 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="8.676200205158938 6.6789420319887975 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.892066735052979 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </tra

# %%
calc = Vasp(directory='adsorcao/benzene-Ag111-center',
            xc='PBE',
            kpts=[4,4,1],  
            encut=450,
            ivdw=12,                    # Adicionando correção de van der Waals D3(BJ) (molécula grande)
            ibrion=2,
            nsw=100,
            lvtot=True,                # keep LOCPOT for post-processing
            atoms=ads_system)

E_ads_center = ads_system.get_potential_energy()

# %% [markdown]
# Demorou 106min 52s

# %%
print("Energia do sistema Ag(111) + benzeno (center) = {:.3f} eV".format(E_ads_center))
# Out:
# Energia do sistema Ag(111) + benzeno (center) = -155.250 eV

# %% [markdown]
# Energia do sistema Ag(111) + benzeno (center) = -155.250 eV

# %%
Hads_benz_center = E_ads_center - E_slab_vdw - E_bezeno

print("Energia de adsorção do benzeno na posição center do slab Ag(111) = {:.3f} eV".format(Hads_benz_center))
# Out:
# Energia de adsorção do benzeno na posição center do slab Ag(111) = -0.683 eV

# %% [markdown]
# Energia de adsorção do benzeno na posição center do slab Ag(111) = -0.683 eV

# %%
view(ads_system, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 49.445450403942274">
#     <group/>
#   </viewpoint>
#   <transform translation="-4.338100102579469 -3.756904892993699 -12.361362600985569">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.676200205158938 0.0 0.0 13.014300307738408 7.513809785987398 0.0 4.338100102579469 7.513809785987398 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 24.722725201971137">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.676200205158938 0.0 0.0 13.014300307738408 7.513809785987398 0.0 4.338100102579469 7.513809785987398 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.676200205158938 0.0 0.0 8.676200205158938 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 7.513809785987398 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 8.676200205158938 0.0 0.0 8.676200205158938 0.0 24.722725201971137 0.0 0.0 24.722725201971137 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="1.4460333675264896 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579468 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="7.230166837632448 0.8348677539985997 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.892066735052979 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105958 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="8.676200205158938 3.3394710159943988 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 5.844074277990199 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="7.2301668376324475 5.844074277990199 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="10.122233572685428 5.844074277990199 10.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.0500883674871773e-17 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.8920667350529796 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105958 1.6697355079971994 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="1.4460333675264894 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="4.338100102579469 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="7.230166837632448 4.174338769992998 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.892066735052979 6.6789420319887975 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="5.784133470105958 6.6789420319887975 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="8.676200205158938 6.6789420319887975 12.361362600985569">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </transform>
#         <transform translation="2.892066735052979 0.0 14.722725201971139">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.753 0.753 0.753"/>
#             </appearance>
#             <sphere radius="1.45"/>
#           </shape>
#         </tra

# %%
ads_system.get_chemical_symbols()[26:28]
# Out:
# ['Ag', 'C']

# %%
c_benzene = ads_system.get_positions()[27]

slab_top = ads_system.get_positions()[26]

print("Distância do benzeno até o topo do slab: {:.3f} Å".format(c_benzene[2]-slab_top[2]))
# Out:
# Distância do benzeno até o topo do slab: 3.110 Å

# %% [markdown]
# Distância do benzeno até o topo do slab: 3.110 Å
